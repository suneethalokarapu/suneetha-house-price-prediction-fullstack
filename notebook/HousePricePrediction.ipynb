# %%
import matplotlib.pyplot as plt
import pandas as pd
data = pd.read_csv(r"C:\Users\satya\Downloads\housing.csv\housing.csv")
data.head
data.isnull().sum()
data.dtypes
# Out:
# longitude             float64
# latitude              float64
# housing_median_age    float64
# total_rooms           float64
# total_bedrooms        float64
# population            float64
# households            float64
# median_income         float64
# median_house_value    float64
# ocean_proximity        object
# dtype: object

# %%
data['total_bedrooms'] = data['total_bedrooms'].fillna(
    data['total_bedrooms'].median())

# %%
data = pd.get_dummies(
    data,
    columns=['ocean_proximity'],
    drop_first=True
)
data.dtypes
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 data = pd.get_dummies(
#       2     data,
#       3     columns=['ocean_proximity'],
#       4     drop_first=True
#       5 )
#       6 data.dtypes
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\reshape\encoding.py:170, in get_dummies(data, prefix, prefix_sep, dummy_na, columns, sparse, drop_first, dtype)
#     168     raise TypeError("Input must be a list-like for parameter `columns`")
#     169 else:
# --> 170     data_to_encode = data[columns]
#     172 # validate prefixes and separator to avoid silently dropping cols
#     173 def check_len(item, name: str):
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\frame.py:4119, in DataFrame.__getitem__(self, key)
#    4117     if is_iterator(key):
#    4118         key = list(key)
# ...

# %%
print(data.columns)
x = data.drop('median_house_value',axis=1)
y = data['median_house_value']
x.dtypes
# Out:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income',
#        'median_house_value', 'ocean_proximity_INLAND',
#        'ocean_proximity_ISLAND', 'ocean_proximity_NEAR BAY',
#        'ocean_proximity_NEAR OCEAN'],
#       dtype='object')
# longitude                     float64
# latitude                      float64
# housing_median_age            float64
# total_rooms                   float64
# total_bedrooms                float64
# population                    float64
# households                    float64
# median_income                 float64
# ocean_proximity_INLAND           bool
# ocean_proximity_ISLAND           bool
# ocean_proximity_NEAR BAY         bool
# ocean_proximity_NEAR OCEAN       bool
# dtype: object

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size= 0.2,random_state=42)
x_test.dtypes
# Out:
# longitude                     float64
# latitude                      float64
# housing_median_age            float64
# total_rooms                   float64
# total_bedrooms                float64
# population                    float64
# households                    float64
# median_income                 float64
# ocean_proximity_INLAND           bool
# ocean_proximity_ISLAND           bool
# ocean_proximity_NEAR BAY         bool
# ocean_proximity_NEAR OCEAN       bool
# dtype: object

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

X_train = scaler.fit_transform(x_train)
X_test = scaler.transform(x_test)

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()

model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_test)

# %%
import pandas as pd

results = pd.DataFrame({
    'Actual': y_test,
    'Predicted': y_pred
})

print(results.head())
from sklearn.metrics import r2_score

r2 = r2_score(y_test, y_pred)
print("R2 Score:", r2)
# Out:
#          Actual      Predicted
# 20046   47700.0   54055.448899
# 3024    45800.0  124225.338937
# 15663  500001.0  255489.379492
# 20484  218600.0  268002.431569
# 9814   278000.0  262769.434816
# R2 Score: 0.6254240620553605

# %%
from sklearn.ensemble import RandomForestRegressor

rf = RandomForestRegressor(
    n_estimators=100,
    random_state=42
)

rf.fit(X_train, y_train)

y_pred_rf = rf.predict(X_test)

print(r2_score(y_test, y_pred_rf))
# Out:
# 0.8167090228826115

# %%
import pandas as pd

results = pd.DataFrame({
    'Actual': y_test,
    'Predicted': y_pred_rf
})

print(results.head())
# Out:
#          Actual  Predicted
# 20046   47700.0    51521.0
# 3024    45800.0    69792.0
# 15663  500001.0   466710.4
# 20484  218600.0   247533.0
# 9814   278000.0   268843.0

# %%
from sklearn.metrics import r2_score

r2 = r2_score(y_test, y_pred_rf)
print("R2 Score:", r2)
# Out:
# R2 Score: 0.8167090228826115

# %%
import joblib

# %%
joblib.dump(rf, "house_price_model.pkl")
# Out:
# ['house_price_model.pkl']

# %%
joblib.dump(scaler, "scaler.pkl")
# Out:
# ['scaler.pkl']

# %%
import os

print(os.listdir())
# Out:
# ['.android', '.ansys', '.appletviewer', '.conda', '.config', '.copilot', '.emulator_console_auth_token', '.expo', '.fluentconf', '.gitconfig', '.gradle', '.idlerc', '.ipynb_checkpoints', '.ipython', '.jupyter', '.matplotlib', '.node_repl_history', '.redhat', '.sf', '.sfdx', '.vscode', '8a', 'addmux.py', 'AndroidStudioProjects', 'AppData', 'Application Data', 'armstrongfun.py', 'Avengers', 'boiler.bak', 'boiler.dwg', 'cleanup-fluent-LAPTOP-U39I7EDM-11136.bat', 'combine.py', 'Contacts', 'Cookies', 'count,py.py', 'cycle.py', 'data.npy', 'data.txt', 'dict.py', 'Documents', 'Downloads', 'exception.py', 'exp11.ipynb', 'exp13.ipynb', 'exp3.ipynb', 'exp4.ipynb', 'exp5.ipynb', 'exp6.ipynb', 'experiment1.py', 'expo', 'Favorites', 'fghj.py', 'fluent-20250930-092754-6628.trn', 'fml1.ipynb', 'frency.py', 'grade.py', 'hg;lk.py', 'housePrediction.ipynb', 'HousePricePrediction.ipynb', 'house_prediction', 'house_price_model.pkl', 'housing_prediction.ipynb', 'importdataset.py', 'iter.py', 'key.py', 'L
# ...

# %%
import joblib

model = joblib.load("house_price_model.pkl")

scaler = joblib.load("scaler.pkl")

print(type(model))
print(type(scaler))
# Out:
# <class 'sklearn.ensemble._forest.RandomForestRegressor'>
# <class 'sklearn.preprocessing._data.StandardScaler'>

# %%
import joblib

joblib.dump(
    rf,
    r"C:\suneetha\projects\HousePricePrediction\backend\house_price_model.pkl"
)
# Out:
# ['C:\\suneetha\\projects\\HousePricePrediction\\backend\\house_price_model.pkl']

# %%
joblib.dump(
    scaler,
    r"C:\suneetha\projects\HousePricePrediction\backend\scaler.pkl"
)
# Out:
# ['C:\\suneetha\\projects\\HousePricePrediction\\backend\\scaler.pkl']
